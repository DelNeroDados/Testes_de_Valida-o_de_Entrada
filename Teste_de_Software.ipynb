# %% [markdown]
# # PROJETO INTEGRADOR I - TESTE DE SOFTWARE: SITE DOS CORREIOS

# %% [markdown]
# ## 1. Importações

# %%
# Importando Webdriver
from selenium import webdriver

# Importando Service
from selenium.webdriver.chrome.service import Service

# Importando ChromeDriverManager
from webdriver_manager.chrome import ChromeDriverManager

# Importando By
from selenium.webdriver.common.by import By

# Importando Exceções
from selenium.common.exceptions import NoSuchElementException

# Importando  workbook
from openpyxl import workbook

# Importando Condições de Exceção
from selenium.webdriver.support import expected_conditions as EC

# Importando Time
import time

# Definindo a veriável "espere"
espere = 2

# %% [markdown]
# ## 2. Definindo opções do WebDriver

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\joaol\downloads",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

servico = Service(ChromeDriverManager().install())

# %% [markdown]
# ## 3. Tabela

# %%
import pandas as pd

tabela = pd.read_excel("nomes_teste.xlsx")
display(tabela)
# Out:
#        nome          sobrenome                        teste
# 0      joao              Silva               nome minúsculo
# 1         j              Silva               nome - 1 letra
# 2        jo              Silva              nome - 2 letras
# 3       joa              Silva              nome - 3 letras
# 4      joao              Silva              nome - 4 letras
# 5      joão              Silva              nome - completo
# 6         J              Silva               nome - 1 letra
# 7      João              Silva               nome - 1 letra
# 8      J6ão              Silva             nome com números
# 9      5oão              Silva             nome com números
# 10    Jo~ao              Silva             nome com números
# 11     Jo2o              Silva             nome com números
# 12     Joa6              Silva             nome com números
# 13    J oão              Silva             nome com espaços
# 14    Jo ão              Silva             nome com espaços
# 15    Joã o              Silva             nome com espaços
# 16    Jjoão              Silva      nome com letra repetida
# 17   Jjjoão              Silva      nome com letra repetida
# 18  Jjjjoão              Silva      nome com letra repetida
# 19     Jjão              Silva      nome com letra repetida
# 20     Jjjo              Silva      nome com letra repetida
# 21    Jjjjj              Silva      nome com letra repetida
# 22     Jojo              Silva      nome com letra repetida
# 23  J o ã o              Silva             nome com espaços
# 24    J_oão              Silva           nome com underline
# 25    J-oão              Silva               nome com hífen
# 26     J*ão              Silva           nome com asterisco
# 27     Jo@o              Silva              nome com arroba
# 28     Joa#              Silva             nome com hashtag
# 29     Jöao              Silva               nome com trema
# 30     Jöão              Silva        nome com dois acentos
# 31     J&ão              Silva         nome com e comercial
# 32  Jo (ao)              Silva          nome com parênteses
# 33  João da              Silva          nome com preposição
# 34     João           da Silva     sobrenome com preposição
# 35     João          das Silva  sobrenome só com preposição
# 36     João            d Silva     sobrenome com preposição
# 37     João             dSilva     sobrenome com preposição
# 38     João            d'Silva      sobrenome com apostrofe
# 39     João          das Silva     sobrenome com preposição
# 40     João        Silva Silva        sobrenome repetido 2x
# 41     João  Silva Silva Silva        sobrenome repetido 3x

# %% [markdown]
# ## 4. TESTE GOOGLE

# %%
##### Teste de Nome #####

for linha in tabela.index:

    #Variáveis
    navegador = webdriver.Chrome(service=servico, options=options)
    nome = tabela.loc[linha, "nome"]
    sobrenome = tabela.loc[linha, "sobrenome"]
    teste = tabela.loc[linha, "teste"]
    time.sleep(espere)
    #Tela cheia
    options.add_argument("--start-maximized")
    #Abrir site da Google
    navegador.get("https://accounts.google.com/lifecycle/steps/signup/name?continue=https://mail.google.com/mail/u/0/?hl%3Dpt-BR&ddm=0&dsh=S33668011:1717023064263851&emr=1&flowEntry=SignUp&flowName=GlifWebSignIn&followup=https://mail.google.com/mail/u/0/?hl%3Dpt-BR&hl=pt-BR&ifkv=AaSxoQyazh_L522O8eYxSIuHgGbJzq88Zs9Zp5RofK4hxNWZeAezTvajVjNGQXl2wPalBpu701NLPg&osid=1&service=mail&TL=ALv_Gf8UCQFEk96-iq3NgJ36lNaQXSjl_JAEg6sYDkC2tP7VF5R6oJG_mzDTKWe4")
    time.sleep(espere)
    navegador.find_element(By.XPATH, '//*[@id="yDmH0d"]/c-wiz/div/div[3]/div/div/div/div/button').click()
    time.sleep(espere)
    
    # Verifica se a linha está vazia
    if tabela.iloc[linha].isnull().all() or (tabela.iloc[linha] == '').all():
        break

    #Enviar nome
    navegador.find_element(By.XPATH, '//*[@id="firstName"]').send_keys(nome)
    time.sleep(espere)

    #Enviar sobrenome
    navegador.find_element(By.XPATH, '//*[@id="lastName"]').send_keys(sobrenome)
    time.sleep(espere)

    #Clicar Avançar
    label_element = navegador.find_element(By.XPATH, "//*[contains(text(), 'Avançar')]")
    label_element.click()
    time.sleep(espere)

    ##### Condição de erro #####
    try:
        element = navegador.find_element(By.XPATH, "//*[contains(text(), 'Tem certeza de que inseriu seu nome corretamente?')]")
        error = element.text
        error_present = True
    except NoSuchElementException:
        error_present = False
        
    ##### Teste IF #####
    if error_present == True:
        print(nome, " - ", teste, "- recusado")
        time.sleep(espere)
        pass
    else:
        print(nome, " - ", teste, "- aceito")
        time.sleep(espere)
        pass
    navegador.quit()
# Out:
# joao  -  nome minúsculo - aceito
# j  -  nome - 1 letra - aceito
# jo  -  nome - 2 letras - aceito
# joa  -  nome - 3 letras - aceito
# joao  -  nome - 4 letras - aceito
# joão  -  nome - completo - aceito
# J  -  nome - 1 letra - aceito
# João  -  nome - 1 letra - aceito
# J6ão  -  nome com números - aceito
# 5oão  -  nome com números - aceito
# Jo~ao  -  nome com números - recusado
# Jo2o  -  nome com números - aceito
# Joa6  -  nome com números - aceito
# J oão  -  nome com espaços - aceito
# Jo ão  -  nome com espaços - aceito
# Joã o  -  nome com espaços - aceito
# Jjoão  -  nome com letra repetida - aceito
# Jjjoão  -  nome com letra repetida - aceito
# Jjjjoão  -  nome com letra repetida - aceito
# Jjão  -  nome com letra repetida - aceito
# Jjjo  -  nome com letra repetida - aceito
# Jjjjj  -  nome com letra repetida - recusado
# Jojo  -  nome com letra repetida - aceito
# J o ã o  -  nome com espaços - aceito
# J_oão  -  nome com underline - aceito
# J-oão  -  nome com hífen - aceito
# J*ão  -  nome com asterisco - aceito
# Jo@o  -  nome com arroba - recusado
# Joa#  -  nome com hashtag - aceito
# Jöao  -  nome com trema - aceito
# Jöão  -  nome com dois acentos - aceito
# J&ão  -  nome com e comercial - aceito
# Jo (ao)  -  nome com parênteses - recusado
# João da  -  nome com preposição - aceito
# João  -  sobrenome com preposição - aceito
# João  -  sobrenome só com preposição - aceito
# João  -  sobrenome com preposição - aceito
# João  -  sobrenome com preposição - aceito
# João  -  sobrenome com apostrofe - aceito
# João  -  sobrenome com preposição - aceito
# João  -  sobrenome repetido 2x - aceito
# João  -  sobrenome repetido 3x - aceito
